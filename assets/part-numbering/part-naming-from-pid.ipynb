# %%
import numpy as np
import pandas as pd
import math

# %%
# Path to the csv file
path="700000-lower-extremity/"
file="700000-Lower-Extremity-Bones"

# %%
# Read the csv file
data = pd.read_csv(path+file+".csv")
#data = pd.read_csv("../part-numbering/600000-Pelvis/601000-Pelvis-Bones.csv") 
num_of_rows=data.shape[0]

# %%
# Check first few rows
data.head()
# Check the whole table
# data
# Out:
#    Body Region  Sagittal Aspect  Component  Unnamed: 3  Unnamed: 4  \
# 0          7.0              NaN        NaN         NaN         NaN
# 1          NaN              0.0        NaN         NaN         NaN
# 2          NaN              5.0        NaN         NaN         NaN
# 3          NaN              NaN        1.0         NaN         NaN
# 4          NaN              NaN        NaN         NaN        11.0
#
#    Sub-Comp\r\n/Material   Part Name  Comment
# 0                    NaN          LX      NaN
# 1                    NaN           L      NaN
# 2                    NaN           R      NaN
# 3                    NaN        Bone      NaN
# 4                    NaN  Femur-head      NaN

# %%
pid = 0
name = ''

# %%
dic = {}
for n in range(num_of_rows):
        if pd.notna(data.iloc[n,0]):
            first = data.iloc[n,0]
            body_region = str(data.iloc[n,6])
            
            second = []
            third = []
            fourth = []
            fifth = []
            sixth = []
            
            sagittal_aspect = []
            third_name = []
            fourth_name = []
            fifth_name = []
            sixth_name = []
            continue
            
        if pd.notna(data.iloc[n,1]):
            second.append(int(data.iloc[n,1]))
            sagittal_aspect.append(str(data.iloc[n,6]))
            #print(second,sagittal_aspect)
            continue
            
        if pd.notna(data.iloc[n,2]):
            third.append(int(data.iloc[n,2]))
            #if pd.notna(data.iloc[n,6]):
            third_name.append(str(data.iloc[n,6]))
            continue
            
        if pd.notna(data.iloc[n,3]):
            fourth.append(int(data.iloc[n,3]))
            #if pd.notna(data.iloc[n,6]):
            fourth_name.append(str(data.iloc[n,6]))
            continue
            
        if pd.notna(data.iloc[n,4]):
            fifth.append(int(data.iloc[n,4]))
            #if pd.notna(data.iloc[n,6]):
            fifth_name.append(str(data.iloc[n,6]))
            continue
            
        if pd.notna(data.iloc[n,5]):
            sixth.append(int(data.iloc[n,5]))
            sixth_name.append(str(data.iloc[n,6]))
            #print(sixth,sixth_name)
            
# Loop through the list to create PID and PID names
# Takes the digits and corresponding names in the csv and writes them to a dictionary

for s1,s2 in zip(second,sagittal_aspect):
    for t1,t2 in zip(third,third_name):
        for fi1,fi2 in zip(fifth,fifth_name):
            # Check if the fourth place in the csv is empty
            if fourth == []:
                # Check if the sixth place in the csv is empty
                if sixth == []:
                    
                    print(s1,t1,fi1,s2,t2,fi2)
                                #if math.isnan(si1):
                                    #si1=0
                
                                #if math.isnan(f1):
                    pid = int(first*10**5 + s1*10**4 + t1*10**3 + fi1*10)    
                    name = body_region + '-' + str(t2) + '-' + str(fi2) + '-'  + str(s2)
                    dic[pid]= name
                                #else:
                                   # pid = int(first*10**5 + s1*10**4 + t1*10**3 + f1*100 + fi1*10 +si1)    
                                    #name = body_region + '-' + str(t2) + '-' + str(f2) + '-'+ str(fi2) + '-' + str(si2) + '-' + str(s2)
                                   #dic[pid]= name
                else:
                    for si1,si2 in zip(sixth,sixth_name):
                        print(3)
                        print(s1,t1,fi1,si1,s2,t2,fi2,si2)
                        pid = int(first*10**5 + s1*10**4 + t1*10**3 + fi1*10 +si1)    
                        name = body_region + '-' + str(t2) + '-' + str(fi2) + '-' + str(si2) + '-' + str(s2)
                        dic[pid]= name
            # Actions if the fourth place is not empty            
            else:    
                for f1,f2 in zip(fourth,fourth_name):
                    # Check if the sixth place is empty
                    if sixth == []:
                    
                        #print(s1,t1,f1,fi1,s2,t2,f2,fi2)
                                #if math.isnan(si1):
                                    #si1=0
                
                                #if math.isnan(f1):
                        pid = int(first*10**5 + s1*10**4 + t1*10**3 + f1*100 + fi1*10)    
                        name = body_region + '-' + str(t2) + '-' + str(f2) + '-' + str(fi2) + '-'  + str(s2)
                        dic[pid]= name
                                #else:
                                   # pid = int(first*10**5 + s1*10**4 + t1*10**3 + f1*100 + fi1*10 +si1)    
                                    #name = body_region + '-' + str(t2) + '-' + str(f2) + '-'+ str(fi2) + '-' + str(si2) + '-' + str(s2)
                                   #dic[pid]= name
                    else:
                        for si1,si2 in zip(sixth,sixth_name):
                            print(6)
                            print(s1,t1,f1,fi1,si1,s2,t2,f2,fi2,si2)
                            pid = int(first*10**5 + s1*10**4 + t1*10**3 + fi1*10 +si1)    
                            name = body_region + '-' + str(t2) + '-' + str(f2) + '-' + str(fi2) + '-' + str(si2) + '-' + str(s2)
                            dic[pid]= name
                    
                                    
#print (dic)
# Out:
# 3
# 0 1 11 1 L Bone Femur-head Cortical
# 3
# 0 1 11 2 L Bone Femur-head Trabecular
# 3
# 0 1 11 3 L Bone Femur-head Rigid
# 3
# 0 1 12 1 L Bone Femur-neck Cortical
# 3
# 0 1 12 2 L Bone Femur-neck Trabecular
# 3
# 0 1 12 3 L Bone Femur-neck Rigid
# 3
# 0 1 13 1 L Bone Femur-greater-trochanter Cortical
# 3
# 0 1 13 2 L Bone Femur-greater-trochanter Trabecular
# 3
# 0 1 13 3 L Bone Femur-greater-trochanter Rigid
# 3
# 0 1 14 1 L Bone Femur-lesser-trochanter Cortical
# 3
# 0 1 14 2 L Bone Femur-lesser-trochanter Trabecular
# 3
# 0 1 14 3 L Bone Femur-lesser-trochanter Rigid
# 3
# 0 1 15 1 L Bone Femur-shaft-proximal Cortical
# 3
# 0 1 15 2 L Bone Femur-shaft-proximal Trabecular
# 3
# 0 1 15 3 L Bone Femur-shaft-proximal Rigid
# 3
# 0 1 16 1 L Bone Femur-shaft-middle Cortical
# 3
# 0 1 16 2 L Bone Femur-shaft-middle Trabecular
# 3
# 0 1 16 3 L Bone Femur-shaft-middle Rigid
# 3
# 0 1 17 1 L Bone Femur-shaft-distal Cortical
# 3
# 0 1 17 2 L Bone Femur-shaft-distal Trabecular
# 3
# 0 1 17 3 L Bone Femur-shaft-distal Rigid
# 3
# 0 1 18 1 L Bone Femur-distal-medial-condyle Cortical
# 3
# 0 1 18 2 L Bone Femur-distal-medial-condyle Trabecular
# 3
# 0 1 18 3 L Bone Femur-distal-medial-condyle Rigid
# 3
# 0 1 19 1 L Bone Femur-distal-intercondylar-fossa Cortical
# 3
# 0 1 19 2 L Bone Femur-distal-intercondylar-fossa Trabecular
# 3
# 0 1 19 3 L Bone Femur-distal-intercondylar-fossa Rigid
# 3
# 0 1 20 1 L Bone Femur-distal-lateral-condyle Cortical
# 3
# 0 1 20 2 L Bone Femur-distal-lateral-condyle Trabecular
# 3
# 0 1 20 3 L Bone Femur-distal-lateral-condyle Rigid
# 3
# 0 1 30 1 L Bone Patella Cortical
# 3
# 0 1 30 2 L Bone Patella Trabecular
# 3
# 0 1 30 3 L Bone Patella Rigid
# 3
# 0 1 41 1 L Bone Tibia-proximal Cortical
# 3
# 0 1 41 2 L Bone Tibia-proximal Trabecular
# 3
# 0 1 41 3 L Bone Tibia-proximal Rigid
# 3
# 0 1 42 1 L Bone Tibia-shaft Cortical
# 3
# 0 1 42 2 L Bone Tibia-shaft Trabecular
# 3
# 0 1 42 3 L Bone Tibia-shaft Rigid
# 3
# 0 1 43 1 L Bone Tibia-distal Cortical
# 3
# 0 1 43 2 L Bone Tibia-distal Trabecular
# 3
# 0 1 43 3 L Bone Tibia-distal Rigid
# 3
# 0 1 61 1 L Bone Fibula-proximal Cortical
# 3
# 0 1 61 2 L Bone Fibula-proximal Trabecular
# 3
# 0 1 61 3 L Bone Fibula-proximal Rigid
# 3
# 0 1 62 1 L Bone Fibula-shaft Cortical
# 3
# 0 1 62 2 L Bone Fibula-shaft Trabecular
# 3
# 0 1 62 3 L Bone Fibula-shaft Rigid
# 3
# 0 1 63 1 L Bone Fibula-distal Cortical
# 3
# 0 1 63 2 L Bone Fibula-distal Trabecular
# 3
# 0 1 63 3 L Bone Fibula-distal Rigid
# 3
# 5 1 11 1 R Bone Femur-head Cortical
# 3
# 5 1 11 2 R Bone Femur-head Trabecular
# 3
# 5 1 11 3 R Bone Femur-head Rigid
# 3
# 5 1 12 1 R Bone Femur-neck Cortical
# 3
# 5 1 12 2 R Bone Femur-neck Trabecular
# 3
# 5 1 12 3 R Bone Femur-neck Rigid
# 3
# 5 1 13 1 R Bone Femur-greater-trochanter Cortical
# 3
# 5 1 13 2 R Bone Femur-greater-trochanter Trabecular
# 3
# 5 1 13 3 R Bone Femur-greater-trochanter Rigid
# 3
# 5 1 14 1 R Bone Femur-lesser-trochanter Cortical
# 3
# 5 1 14 2 R Bone Femur-lesser-trochanter Trabecular
# 3
# 5 1 14 3 R Bone Femur-lesser-trochanter Rigid
# 3
# 5 1 15 1 R Bone Femur-shaft-proximal Cortical
# 3
# 5 1 15 2 R Bone Femur-shaft-proximal Trabecular
# 3
# 5 1 15 3 R Bone Femur-shaft-proximal Rigid
# 3
# 5 1 16 1 R Bone Femur-shaft-middle Cortical
# 3
# 5 1 16 2 R Bone Femur-shaft-middle Trabecular
# 3
# 5 1 16 3 R Bone Femur-shaft-middle Rigid
# 3
# 5 1 17 1 R Bone Femur-shaft-distal Cortical
# 3
# 5 1 17 2 R Bone Femur-shaft-distal Trabecular
# 3
# 5 1 17 3 R Bone Femur-shaft-distal Rigid
# 3
# 5 1 18 1 R Bone Femur-distal-medial-condyle Cortical
# 3
# 5 1 18 2 R Bone Femur-distal-medial-condyle Trabecular
# 3
# 5 1 18 3 R Bone Femur-distal-medial-condyle Rigid
# 3
# 5 1 19 1 R Bone Femur-distal-intercondylar-fossa Cortical
# 3
# 5 1 19 2 R Bone Femur-distal-intercondylar-fossa Trabecular
# 3
# 5 1 19 3 R Bone Femur-distal-intercondylar-fossa Rigid
# 3
# 5 1 20 1 R Bone Femur-distal-lateral-condyle Cortical
# 3
# 5 1 20 2 R Bone Femur-distal-lateral-condyle Trabecular
# 3
# 5 1 20 3 R Bone Femur-distal-lateral-condyle Rigid
# 3
# 5 1 30 1 R Bone Patella Cortical
# 3
# 5 1 30 2 R Bone Patella Trabecular
# 3
# 5 1 30 3 R Bone Patella Rigid
# 3
# 5 1 41 1 R Bone Tibia-proximal Cortical
# 3
# 5 1 41 2 R Bone Tibia-proximal Trabecular
# 3
# 5 1 41 3 R Bone Tibia-proximal Rigid
# 3
# 5 1 42 1 R Bone Tibia-shaft Cortical
# 3
# 5 1 42 2 R Bone Tibia-shaft Trabecular
# 3
# 5 1 42 3 R Bone Tibia-shaft Rigid
# 3
# 5 1 43 1 R Bone Tibia-distal Cortical
# 3
# 5 1 43 2 R Bone Tibia-distal Trabecular
# 3
# 5 1 43 3 R Bone Tibia-distal Rigid
# 3
# 5 1 61 1 R Bone Fibula-proximal Cortical
# 3
# 5 1 61 2 R Bone Fibula-proximal Trabecular
# 3
# 5 1 61 3 R Bone Fibula-proximal Rigid
# 3
# 5 1 62 1 R Bone Fibula-shaft Cortical
# 3
# 5 1 62 2 R Bone Fibula-shaft Trabecular
# 3
# 5 1 62 3 R Bone Fibula-shaft Rigid
# 3
# 5 1 63 1 R Bone Fibula-distal Cortical
# 3
# 5 1 63 2 R Bone Fibula-distal Trabecular
# 3
# 5 1 63 3 R Bone Fibula-distal Rigid

# %%
dic
# Out:
# {701111: 'LX-Bone-Femur-head-Cortical-L',
#  701112: 'LX-Bone-Femur-head-Trabecular-L',
#  701113: 'LX-Bone-Femur-head-Rigid-L',
#  701121: 'LX-Bone-Femur-neck-Cortical-L',
#  701122: 'LX-Bone-Femur-neck-Trabecular-L',
#  701123: 'LX-Bone-Femur-neck-Rigid-L',
#  701131: 'LX-Bone-Femur-greater-trochanter-Cortical-L',
#  701132: 'LX-Bone-Femur-greater-trochanter-Trabecular-L',
#  701133: 'LX-Bone-Femur-greater-trochanter-Rigid-L',
#  701141: 'LX-Bone-Femur-lesser-trochanter-Cortical-L',
#  701142: 'LX-Bone-Femur-lesser-trochanter-Trabecular-L',
#  701143: 'LX-Bone-Femur-lesser-trochanter-Rigid-L',
#  701151: 'LX-Bone-Femur-shaft-proximal-Cortical-L',
#  701152: 'LX-Bone-Femur-shaft-proximal-Trabecular-L',
#  701153: 'LX-Bone-Femur-shaft-proximal-Rigid-L',
#  701161: 'LX-Bone-Femur-shaft-middle-Cortical-L',
#  701162: 'LX-Bone-Femur-shaft-middle-Trabecular-L',
#  701163: 'LX-Bone-Femur-shaft-middle-Rigid-L',
#  701171: 'LX-Bone-Femur-shaft-distal-Cortical-L',
#  701172: 'LX-Bone-Femur-shaft-distal-Trabecular-L',
#  701173: 'LX-Bone-Femur-shaft-distal-Rigid-L',
#  701181: 'LX-Bone-Femur-distal-medial-condyle-Cortical-L',
#  701182: 'LX-Bone-Femur-distal-medial-condyle-Trabecular-L',
#  701183: 'LX-Bone-Femur-distal-medial-condyle-Rigid-L',
#  701191: 'LX-Bone-Femur-distal-intercondylar-fossa-Cortical-L',
#  701192: 'LX-Bone-Femur-distal-intercondylar-fossa-Trabecular-L',
#  701193: 'LX-Bone-Femur-distal-intercondylar-fossa-Rigid-L',
#  701201: 'LX-Bone-Femur-distal-lateral-condyle-Cortical-L',
#  701202: 'LX-Bone-Femur-distal-lateral-condyle-Trabecular-L',
#  701203: 'LX-Bone-Femur-distal-lateral-condyle-Rigid-L',
#  701301: 'LX-Bone-Patella-Cortical-L',
#  701302: 'LX-Bone-Patella-Trabecular-L',
#  701303: 'LX-Bone-Patella-Rigid-L',
#  701411: 'LX-Bone-Tibia-proximal-Cortical-L',
#  701412: 'LX-Bone-Tibia-proximal-Trabecular-L',
#  701413: 'LX-Bone-Tibia-proximal-Rigid-L',
#  701421: 'LX-Bone-Tibia-shaft-Cortical-L',
#  701422: 'LX-Bone-Tibia-shaft-Trabecular-L',
#  701423: 'LX-Bone-Tibia-shaft-Rigid-L',
#  701431: 'LX-Bone-Tibia-distal-Cortical-L',
#  701432: 'LX-Bone-Tibia-distal-Trabecular-L',
#  701433: 'LX-Bone-Tibia-distal-Rigid-L',
#  701611: 'LX-Bone-Fibula-proximal-Cortical-L',
#  701612: 'LX-Bone-Fibula-proximal-Trabecular-L',
#  701613: 'LX-Bone-Fibula-proximal-Rigid-L',
#  701621: 'LX-Bone-Fibula-shaft-Cortical-L',
#  701622: 'LX-Bone-Fibula-shaft-Trabecular-L',
#  701623: 'LX-Bone-Fibula-shaft-Rigid-L',
#  701631: 'LX-Bone-Fibula-distal-Cortical-L',
#  701632: 'LX-Bone-Fibula-distal-Trabecular-L',
#  701633: 'LX-Bone-Fibula-distal-Rigid-L',
#  751111: 'LX-Bone-Femur-head-Cortical-R',
#  751112: 'LX-Bone-Femur-head-Trabecular-R',
#  751113: 'LX-Bone-Femur-head-Rigid-R',
#  751121: 'LX-Bone-Femur-neck-Cortical-R',
#  751122: 'LX-Bone-Femur-neck-Trabecular-R',
#  751123: 'LX-Bone-Femur-neck-Rigid-R',
#  751131: 'LX-Bone-Femur-greater-trochanter-Cortical-R',
#  751132: 'LX-Bone-Femur-greater-trochanter-Trabecular-R',
#  751133: 'LX-Bone-Femur-greater-trochanter-Rigid-R',
#  751141: 'LX-Bone-Femur-lesser-trochanter-Cortical-R',
#  751142: 'LX-Bone-Femur-lesser-trochanter-Trabecular-R',
#  751143: 'LX-Bone-Femur-lesser-trochanter-Rigid-R',
#  751151: 'LX-Bone-Femur-shaft-proximal-Cortical-R',
#  751152: 'LX-Bone-Femur-shaft-proximal-Trabecular-R',
#  751153: 'LX-Bone-Femur-shaft-proximal-Rigid-R',
#  751161: 'LX-Bone-Femur-shaft-middle-Cortical-R',
#  751162: 'LX-Bone-Femur-shaft-middle-Trabecular-R',
#  751163: 'LX-Bone-Femur-shaft-middle-Rigid-R',
#  751171: 'LX-Bone-Femur-shaft-distal-Cortical-R',
#  751172: 'LX-Bone-Femur-shaft-distal-Trabecular-R',
#  751173: 'LX-Bone-Femur-shaft-distal-Rigid-R',
#  751181: 'LX-Bone-Femur-distal-medial-condyle-Cortical-R',
#  751182: 'LX-Bone-Femur-distal-medial-condyle-Trabecular-R',
#  751183: 'LX-Bone-Femur-distal-medial-condyle-Rigid-R',
#  751191: 'LX-Bone-Femur-distal-intercondylar-fossa-Cortical-R',
#  751192: 'LX-Bone-Femur-distal-intercondylar-fossa-Trabecular-R',
#  751193: 'LX-Bone-Femur-distal-intercondylar-fossa-Rigid-R',
#  751201: 'LX-Bone-Femur-distal-lateral-condyle-Cortical-R',
#  751202: 'LX-Bone-Femur-distal-lateral-condyle-Trabecular-R',
#  751203: 'LX-Bone-Femur-distal-lateral-condyle-Rigid-R',
#  751301: 'LX-Bone-Patella-Cortical-R',
#  751302: 'LX-Bone-Patella-Trabecular-R',
#  751303: 'LX-Bone-Patella-Rigid-R',
#  751411: 'LX-Bone-Tibia-proximal-Cortical-R',
#  751412: 'LX-Bone-Tibia-proximal-Trabecular-R',
#  751413: 'LX-Bone-Tibia-proximal-Rigid-R',
#  751421: 'LX-Bone-Tibia-shaft-Cortical-R',
#  751422: 'LX-Bone-Tibia-shaft-Trabecular-R',
#  751423: 'LX-Bone-Tibia-shaft-Rigid-R',
#  751431: 'LX-Bone-Tibia-distal-Cortical-R',
#  751432: 'LX-Bone-Tibia-distal-Trabecular-R',
#  751433: 'LX-Bone-Tibia-distal-Rigid-R',
#  751611: 'LX-Bone-Fibula-proximal-Cortical-R',
#  751612: 'LX-Bone-Fibula-proximal-Trabecular-R',
#  751613: 'LX-Bone-Fibula-proximal-Rigid-R',
#  751621: 'LX-Bone-Fibula-shaft-Cortical-R',
#  751622: 'LX-Bone-Fibula-shaft-Trabecular-R',
#  751623: 'LX-Bone-Fibula-shaft-Rigid-R',
#  751631: 'LX-Bone-Fibula-distal-Cortical-R',
#  751632: 'LX-Bone-Fibula-distal-Trabecular-R',
#  751633: 'LX-Bone-Fibula-distal-Rigid-R'}

# %%
# Output the dictionary values to a csv
(pd.DataFrame.from_dict(data=dic, orient='index')
     .to_csv(path+file+"-PID-PIDName" + ".csv", header=False))

# %%
#(pd.DataFrame.from_dict(data=dic, orient='index')
#     .to_csv("../part-numbering/600000-Pelvis/601000-Pelvis-Bones-PIDPID.csv", header=False))
